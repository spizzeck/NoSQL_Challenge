# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query ={'scores.Hygiene':{'$eq':20}}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
print('Number of documents in result:', establishments.count_documents(query))
# Display the first document in the results using pprint
results=establishments.find(query)
pprint(results[0])
# Out:
# Number of documents in result: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65638e9461ab86f1255be00a'),
#  'geocode': {'latitude': Decimal128('50.7697050000000'),
#              'longitude': Decimal128('0.276940000000000')},
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_db=pd.DataFrame(results)
# Display the number of rows in the DataFrame
rows_count=len(hygiene_db)
print('Number of rows in db:', rows_count)
# Display the first 10 rows of the DataFrame
hygiene_db.head()
# Out:
# Number of rows in db: 41
#                         _id  FHRSID  ChangesByServerID  \
# 0  65638e9461ab86f1255be00a  110681                  0
# 1  65638e9461ab86f1255be38a  612039                  0
# 2  65638e9461ab86f1255be696  730933                  0
# 3  65638e9461ab86f1255be883  172735                  0
# 4  65638e9461ab86f1255be892  172953                  0
#
#   LocalAuthorityBusinessID         BusinessName  \
# 0                     4029  The Chase Rest Home
# 1                1970/FOOD           Brenalwood
# 2                1698/FOOD        Melrose Hotel
# 3             PI/000023858        Seaford Pizza
# 4             PI/000024532        Golden Palace
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={'LocalAuthorityName': {'$regex':'London'},
        'RatingValue':{'$gte':4}}

# Use count_documents to display the number of documents in the result
print("Number of documents in query:",establishments.count_documents(query))
# Display the first document in the results using pprint
results=establishments.find(query)
pprint(results[0])
# Out:
# Number of documents in query: 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65638e9461ab86f1255bfa23'),
#  'geocode': {'latitude': Decimal128('51.3693210000000'),
# ...

# %%
# Convert the result to a Pandas DataFrame
london_rating_db=pd.DataFrame(results)
# Display the number of rows in the DataFrame
rows_count=len(london_rating_db)
print('Number of rows in db:', rows_count)
# Display the first 10 rows of the DataFrame
london_rating_db.head()
# Out:
# Number of rows in db: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  65638e9461ab86f1255bfa23   621707                  0
# 1  65638e9461ab86f1255bfd4b  1130836                  0
# 2  65638e9461ab86f1255c0898   293783                  0
# 3  65638e9461ab86f1255c1697   294474                  0
# 4  65638e9461ab86f1255c169a  1315095                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# 4             PI/000036464  Coombs Catering t/a The Lock and Key
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
query={'BusinessName':'Penang Flavours'}
results=establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65638e96ea65aca40571ab25'),
#  'geocode': {'latitude': Decimal128('51.4901420000000'),
#              'longitude': Decimal128('0.0838400000000000')},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.4901420
longitude = 0.083840

query ={'geocode.latitude': {'$gte':latitude-degree_search, '$lte': latitude+degree_search},
        'geocode.longitude':{'$gte':longitude-degree_search, '$lte':longitude+degree_search},
        'RatingValue': 5}
sort = [('scores.Hygiene', 1)]  
limit=5
# Print the results
pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65638e9561ab86f1255c3869'),
#   'geocode': {'latitude': Decimal128('51.4873437000000'),
#               'longitude': Decimal128('0.0920800000000000')},
# ...

# %%
# Convert result to Pandas DataFrame
top_rated_proximity_db=pd.DataFrame(establishments.find(query).sort(sort).limit(limit))
top_rated_proximity_db
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65638e9561ab86f1255c3869   694609                  0
# 1  65638e9561ab86f1255c3881   695241                  0
# 2  65638e9561ab86f1255c3884   909912                  0
# 3  65638e9561ab86f1255c383a   695223                  0
# 4  65638e9561ab86f1255c384d  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                      Retailers - other            4613
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query={'$match': {'scores.Hygiene': {'$eq':0}}}
# 2. Groups the matches by Local Authority
group_query={'$group': {'_id': '$LocalAuthorityName', 'number_of_establishments':{'$sum':1}}}
# 3. Sorts the matches from highest to lowest
sort_values={'$sort': {'number_of_establishments':-1}}

pipeline=[match_query, group_query, sort_values]

# %%
# Print the number of documents in the result
results=list(establishments.aggregate(pipeline))
print("Number of documents for Local Authority Area with Hygiene Score of 0:", len(results))
# Out:
# Number of documents for Local Authority Area with Hygiene Score of 0: 55

# %%
# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': 'Thanet', 'number_of_establishments': 1130},
#  {'_id': 'Greenwich', 'number_of_establishments': 882},
#  {'_id': 'Maidstone', 'number_of_establishments': 713},
#  {'_id': 'Newham', 'number_of_establishments': 711},
#  {'_id': 'Swale', 'number_of_establishments': 686},
#  {'_id': 'Chelmsford', 'number_of_establishments': 680},
#  {'_id': 'Medway', 'number_of_establishments': 672},
#  {'_id': 'Bexley', 'number_of_establishments': 607},
#  {'_id': 'Southend-On-Sea', 'number_of_establishments': 586},
#  {'_id': 'Tendring', 'number_of_establishments': 542}]

# %%
# Convert the result to a Pandas DataFrame
local_authority_db=pd.DataFrame(results)
local_authority_db.columns=['Local Authority Name', 'Number of Establishments']
# Display the number of rows in the DataFrame
print("Number of rows in db:", len(local_authority_db))
# Display the first 10 rows of the DataFrame
local_authority_db.head(10)
# Out:
# Number of rows in db: 55
#   Local Authority Name  Number of Establishments
# 0               Thanet                      1130
# 1            Greenwich                       882
# 2            Maidstone                       713
# 3               Newham                       711
# 4                Swale                       686
# 5           Chelmsford                       680
# 6               Medway                       672
# 7               Bexley                       607
# 8      Southend-On-Sea                       586
# 9             Tendring                       542
